# %%
import healpy as hp
import mylib as my
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import os
# Out:
# Welcome to JupyROOT 6.24/06
# 15:30:23 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=819914;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=375845;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#50\50]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=114457;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=901033;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=678129;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=272610;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
# 15:30:24 INFO      Starting 3ML!                                                                     ]8;id=321897;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=531103;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=662568;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=495814;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=978803;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=166774;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=190777;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=452809;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
# 15:30:25 WARNING   Multinest minimizer not available                                           ]8;id=291577;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=841295;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=302443;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=600929;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
# 15:30:25 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=815709;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=516499;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=624991;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=639508;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=320708;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=291668;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   No fermitools installed                                              ]8;id=85701;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=876969;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=517910;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=10079;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=545148;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=740768;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=643052;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=742994;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
# WARNING RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 96, got 80
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 232, got 216
# Yourlib init successful!!!

# %%
# %matplotlib inline

region_name="J0248"
Modelname="JustDraw"
if not os.path.exists(f'../res/{region_name}/{Modelname}/'):
    os.system(f'mkdir ../res/{region_name}/{Modelname}/')
# map2, skymapHeader = hp.read_map("../data/sigts_J0248.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_J0248_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_res_J0248.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_no_diffuse.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("../data/sigts_Diffusion_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_Diffusion_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_gauss_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_20210305-20230731.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_20210305-20230731_DGE_res.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_20210305-20230731_DGE_res.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/data/signif_20210305_20230731_ihep_goodlist_nHit000_0.41.fits.gz.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/data/signif_20210305_20230731_ihep_goodlist_nHit006_0.29.fits.gz.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/3MLWCDA0.91/Standard/src/tools/llh_skymap/sigts_J0248_new.fits.gz",h=True)
map2, skymapHeader = hp.read_map("/data/home/cwy/Science/3MLWCDA0.91/Standard/src/tools/llh_skymap/sigts_siglist_J0248_res_J0248.fits.gz",h=True)

ra1=42.38
dec1=60.37
map2 = hp.ma(map2)
rad=20
fit = my.hpDraw(region_name, Modelname, map2,ra1,dec1,
      radx=rad/np.cos(dec1/180*np.pi),
      rady=rad,
      # contours=[], 
      colorlabel="Significance",
      color="Fermi",
      plotres=True
    )
plt.legend(loc = 'upper left')
# Out:
# TeVCat:  1 31.379166666666666 64.85 3C 58
# TeVCat:  2 33.57458333333333 51.74777777777778 TXS 0210+515
# TeVCat:  3 40.14166666666666 61.25694444444444 LS I +61 303
# TeVCat:  4 55.339999999999996 52.97 LHAASO J0341+5258
# PSR:  1 24.0 63.7 J0136+63
# PSR:  2 24.832249999999995 58.24216666666667 J0139+5814
# PSR:  3 24.910666666666664 56.36022222222223 J0139+5621
# PSR:  4 25.249999999999996 63.13333333333333 J0141+63
# PSR:  5 25.416416666666667 60.15897222222222 J0141+6009
# PSR:  6 26.593416666666663 61.75077777777778 J0146+6145
# PSR:  7 26.93604166666666 59.367583333333336 J0147+5922
# PSR:  8 29.458041666666663 62.20719444444445 J0157+6212
# PSR:  9 30.42225 70.08836111111111 J0201+7005
# PSR:  10 31.408 64.82813888888889 J0205+6449
# PSR:  11 33.2175 52.37916666666667 J0212+5222
# PSR:  12 33.730291666666666 52.37802777777778 J0214+5222
# PSR:  13 33.98595833333333 62.30927777777777 J0215+6218
# PSR:  14 40.645833333333336 62.947222222222216 J0242+62
# PSR:  15 40.75 60.45 J0243+6027
# PSR:  16 42.07758333333333 60.35963888888889 J0248+6021
# PSR:  17 51.23108333333333 52.65869444444444 J0324+5239
# PSR:  18 51.5 67.81666666666666 J0325+67
# PSR:  19 53.24737499999999 54.57877777777778 J0332+5434
# PSR:  20 54.74999999999999 66.73333333333333 J0338+66
# PSR:  21 55.25 57.18333333333333 J0341+5711
# PSR:  22 55.803749999999994 53.21483333333334 J0343+5312
# PSR:  23 59.436749999999996 52.61602777777778 J0357+5236
# PSR:  24 59.49999999999999 66.66666666666667 J0358+66
# PSR:  25 59.72383333333333 54.22047222222223 J0358+5413
# PSR:  26 61.625333333333316 61.64472222222222 J0406+6138
# PSR:  27 62.0 55.0 J0408+551
# PSR:  28 62.0 55.0 J0408+552
# SNR:  1 31.42083333333333 64.81666666666666 G130.7+03.1
# SNR:  2 34.41666666666666 62.75 G132.7+01.3
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.

# %%
hp.mollview(map2)

# %%
from scipy.optimize import curve_fit

def gaussian(x,a,mu,sigma):
    return a*np.exp(-((x-mu)/sigma)**2/2)

bin_y,bin_x,patches=plt.hist(map2.compressed(),bins=100)
plt.close()
bin_x=np.array(bin_x)
bin_y=np.array(bin_y)
fit_range = np.logical_and(bin_x>-5, bin_x<5)
wdt=(bin_x[1]-bin_x[0])/2.
try:
    popt, pcov = curve_fit(
        gaussian,
        bin_x[fit_range] + wdt,
        bin_y[fit_range[:-1]],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
except (ValueError, IndexError):
    popt, pcov = curve_fit(
        gaussian,
        bin_x[:100] + wdt,
        bin_y[:100],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
#popt,pcov = curve_fit(gaussian,bin_x[fit_range[0:-1]]+(bin_x[1]-bin_x[0])/2.,bin_y[fit_range[0:-1]],bounds=([100,-2,0],[50000000,2,10]))
print("************************")
print(popt)
print("************************")
print("max Significance= %.1f"%(max(map2.compressed())))

plt.figure()
#plt.plot([0.,0.],[1,1e6],'k--',linewidth=0.5)
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], 0, 1),
    '--',
    label='expectation',
)
plt.plot((bin_x[:100] + bin_x[1:101]) / 2, bin_y, label="data")
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], popt[1], popt[2]),
    '--',
    label='fit',
)
plt.yscale('log')
plt.xlim(-10,10)
plt.ylim(1,max(bin_y*2))
plt.grid(True)
plt.text(-9.5,max(bin_y),'mean = %f\n width = %f'%(popt[1],popt[2]))
plt.xlabel(r'Significance($\sigma$)')
plt.ylabel("entries")
plt.legend()
# Out:
# ************************
# [ 9.53618324e+02 -1.82214121e-01  1.00621978e+00]
# ************************
# max Significance= 3.0

# %% [markdown]
# ### Coma

# %%
map1, skymapHeader = hp.read_map("../data/signif_gcd_new_nHit006_0.30.fits.gz_other.fits.gz",h=True)

ra1=194.9529
dec1=27.9806
rad = 10
map2 = hp.ma(map1)
mt.hpDraw(map1,ra1,dec1,
      radx=rad,A
      rady=np.cos(dec1/180*np.pi)*rad,
      # contours=[3], 
      colorlabel="Significance",
      color="Fermi"
    )

# %% [markdown]
# ### Perseus

# %%
map1, skymapHeader = hp.read_map("../data/signif_gcd_new_nHit006_0.30.fits.gz_other.fits.gz",h=True)

ra1=49.9467
dec1=41.5131
rad = 10
map2 = hp.ma(map1)
mt.hpDraw(map1,ra1,dec1,
      radx=rad,
      rady=np.cos(dec1/180*np.pi)*rad,
      # contours=[3], 
      colorlabel="Significance",
      color="Fermi"
    )
# Out:
# 49.17916666666666 41.32472222222223 IC 310
# 49.950416666666655 41.51166666666666 NGC 1275
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
# 50.86091666666666 39.74802777777778 J0323+3944
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.

# %% [markdown]
# ### Virgo

# %%
map1, skymapHeader = hp.read_map("../data/signif_gcd_new_nHit006_0.30.fits.gz_other.fits.gz",h=True)

ra1=186.6337
dec1=12.7233
rad = 8
map2 = hp.ma(map1)
mt.hpDraw(map1,ra1,dec1,
      radx=rad,
      rady=np.cos(dec1/180*np.pi)*rad,
      # contours=[3], 
      colorlabel="Significance",
      color="Fermi"
    )
# Out:
# 187.69666666666666 12.397499999999999 M 87
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
