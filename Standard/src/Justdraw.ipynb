# %%
import healpy as hp
import mytools as mt
import mylib as my
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import os
# Out:
# Welcome to JupyROOT 6.24/06
# 16:39:54 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=164111;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=93405;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#50\50]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=949924;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=833540;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=423327;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=721724;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
# 16:39:54 INFO      Starting 3ML!                                                                     ]8;id=757766;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=973252;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=890274;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=575551;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=323407;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=130994;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=572239;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=216209;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=775031;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=65141;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=59742;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=459671;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
# 16:39:55 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=371775;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=899022;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=729309;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=463932;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=149834;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=457898;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 16:39:55 WARNING   No fermitools installed                                              ]8;id=791419;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=813802;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=995830;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=498605;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=731458;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=729006;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=695473;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=408042;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
# WARNING RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 96, got 80
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 232, got 216
# Yourlib init successful!!!

# %%
# %matplotlib inline

region_name="J0248"
Modelname="JustDraw"
if not os.path.exists(f'../res/{region_name}/{Modelname}/'):
    os.system(f'mkdir ../res/{region_name}/{Modelname}/')
# map2, skymapHeader = hp.read_map("../data/sigts_J0248.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_J0248_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_res_J0248.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_no_diffuse.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("../data/sigts_Diffusion_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_Diffusion_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_gauss_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_20210305-20230731.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_20210305-20230731_DGE_res.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_20210305-20230731_DGE_res.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/data/signif_20210305_20230731_ihep_goodlist_nHit000_0.41.fits.gz.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/data/signif_20210305_20230731_ihep_goodlist_nHit006_0.29.fits.gz.fits.gz",h=True)
map2, skymapHeader = hp.read_map("/data/home/cwy/Science/0_Source/Standard/src/mytools/llh_skymap/sigts_siglist_J0248_gaus+2pt+fixDGE_res.fits.gz",h=True)

ra1=42.38
dec1=60.37
map2 = hp.ma(map2)
rad=10
fit = my.hpDraw(region_name, Modelname, map2,ra1,dec1,
      radx=rad/np.cos(dec1/180*np.pi),
      rady=rad,
      # contours=[], 
      colorlabel="Significance",
      color="Fermi",
      plotres=True
    )
plt.legend(loc = 'upper left')
# Out:
# 40.14166666666666 61.25694444444444 LS I +61 303
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
# 33.98595833333333 62.30927777777777 J0215+6218
# 40.645833333333336 62.947222222222216 J0242+62
# 40.75 60.45 J0243+6027
# 42.07758333333333 60.35963888888889 J0248+6021
# 34.41666666666666 62.75 G132.7+01.3
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.

# %%
hp.mollview(map2)

# %%
from scipy.optimize import curve_fit

def gaussian(x,a,mu,sigma):
    return a*np.exp(-((x-mu)/sigma)**2/2)

bin_y,bin_x,patches=plt.hist(map2.compressed(),bins=100)
plt.close()
bin_x=np.array(bin_x)
bin_y=np.array(bin_y)
fit_range = np.logical_and(bin_x>-5, bin_x<5)
wdt=(bin_x[1]-bin_x[0])/2.
try:
    popt, pcov = curve_fit(
        gaussian,
        bin_x[fit_range] + wdt,
        bin_y[fit_range[:-1]],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
except (ValueError, IndexError):
    popt, pcov = curve_fit(
        gaussian,
        bin_x[:100] + wdt,
        bin_y[:100],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
#popt,pcov = curve_fit(gaussian,bin_x[fit_range[0:-1]]+(bin_x[1]-bin_x[0])/2.,bin_y[fit_range[0:-1]],bounds=([100,-2,0],[50000000,2,10]))
print("************************")
print(popt)
print("************************")
print("max Significance= %.1f"%(max(map2.compressed())))

plt.figure()
#plt.plot([0.,0.],[1,1e6],'k--',linewidth=0.5)
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], 0, 1),
    '--',
    label='expectation',
)
plt.plot((bin_x[:100] + bin_x[1:101]) / 2, bin_y, label="data")
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], popt[1], popt[2]),
    '--',
    label='fit',
)
plt.yscale('log')
plt.xlim(-10,10)
plt.ylim(1,max(bin_y*2))
plt.grid(True)
plt.text(-9.5,max(bin_y),'mean = %f\n width = %f'%(popt[1],popt[2]))
plt.xlabel(r'Significance($\sigma$)')
plt.ylabel("entries")
plt.legend()
# Out:
# ************************
# [ 9.53618324e+02 -1.82214121e-01  1.00621978e+00]
# ************************
# max Significance= 3.0

# %% [markdown]
# ### Coma

# %%
map1, skymapHeader = hp.read_map("../data/signif_gcd_new_nHit006_0.30.fits.gz_other.fits.gz",h=True)

ra1=194.9529
dec1=27.9806
rad = 10
map2 = hp.ma(map1)
mt.hpDraw(map1,ra1,dec1,
      radx=rad,A
      rady=np.cos(dec1/180*np.pi)*rad,
      # contours=[3], 
      colorlabel="Significance",
      color="Fermi"
    )

# %% [markdown]
# ### Perseus

# %%
map1, skymapHeader = hp.read_map("../data/signif_gcd_new_nHit006_0.30.fits.gz_other.fits.gz",h=True)

ra1=49.9467
dec1=41.5131
rad = 10
map2 = hp.ma(map1)
mt.hpDraw(map1,ra1,dec1,
      radx=rad,
      rady=np.cos(dec1/180*np.pi)*rad,
      # contours=[3], 
      colorlabel="Significance",
      color="Fermi"
    )
# Out:
# 49.17916666666666 41.32472222222223 IC 310
# 49.950416666666655 41.51166666666666 NGC 1275
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
# 50.86091666666666 39.74802777777778 J0323+3944
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.

# %% [markdown]
# ### Virgo

# %%
map1, skymapHeader = hp.read_map("../data/signif_gcd_new_nHit006_0.30.fits.gz_other.fits.gz",h=True)

ra1=186.6337
dec1=12.7233
rad = 8
map2 = hp.ma(map1)
mt.hpDraw(map1,ra1,dec1,
      radx=rad,
      rady=np.cos(dec1/180*np.pi)*rad,
      # contours=[3], 
      colorlabel="Significance",
      color="Fermi"
    )
# Out:
# 187.69666666666666 12.397499999999999 M 87
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
