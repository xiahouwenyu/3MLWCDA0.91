# %%
import matplotlib, sys,  os
import numpy as np
matplotlib.use('Agg')
import matplotlib.pyplot as plt

from tqdm import tqdm

import healpy as hp
import sys
import os
sys.path.append("/data/home/cwy/Science/3MLWCDA/Standard/src/")
import mylib as my
# Out:
# Load Mymodels:   5%|▌         | 2/38 [00:00<00:04,  7.74it/s]
# Welcome to JupyROOT 6.24/06
# 20:29:59 WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=720088;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=213795;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
# Load Mymap:  11%|█         | 4/38 [00:05<01:15,  2.23s/it]     /data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/numpy/lib/npyio.py:2313: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)
# 20:30:00 INFO      Starting 3ML!                                                                     ]8;id=919606;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=913935;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=113766;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=818180;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=861969;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=271567;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=487600;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=953569;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
# 20:30:02 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=866300;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=696644;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=391540;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=607485;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=553029;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=898024;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 20:30:02 WARNING   No fermitools installed                                              ]8;id=774004;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=634897;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=135832;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=425503;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=468873;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=176774;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=932024;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=509957;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
# Load Myfit:  13%|█▎        | 5/38 [00:07<00:53,  1.62s/it]
# WARNING NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "process_dec_bins" failed type inference due to: Use of unsupported NumPy function 'numpy.einsum' or unsupported use of the function.
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 39:
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
#     ss1_sum = np.einsum('ij,j->i', sflux, ss1) * w1
#     ^
#
# During: typing of get attribute at /data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py (39)
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 39:
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
#     ss1_sum = np.einsum('ij,j->i', sflux, ss1) * w1
#     ^
#
#
#
# WARNING NumbaWarning: Function "process_dec_bins" was compiled in object mode without forceobj=True.
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 38:
# @jit(["float64[:](float64[:,:], float64[:], float64[:], float64[:], float64[:])"], parallel=False)
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
# ^
#
#
#
# WARNING NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 38:
# @jit(["float64[:](float64[:,:], float64[:], float64[:], float64[:], float64[:])"], parallel=False)
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
# ^
#
#
# ReLoad Mycatalog:  61%|██████    | 23/38 [00:09<00:26,  1.80s/it]
# WARNING VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# Load sub from Mystat: : 40it [00:10,  4.40it/s]
# Yourlib init successfully!!!

# %%
savename="KM2A_20240731_PL_3.6"

nside=1024
npix=hp.nside2npix(nside)
skymap=np.zeros(npix)
for i in tqdm(range(768)):
    try:
        data=np.loadtxt(f"sig_no{i}.txt")
    except Exception as e:
        print(i, e)
        continue
    for j in range(len(data)):
        try:
            skymap[int(data[j][0])]=float(data[j][1])
        except Exception as e:
            print(i, e)
            continue
skymap=hp.ma(skymap)
# %matplotlib inline

skymap[skymap>0] = np.ma.sqrt(skymap[skymap>0])
skymap[skymap<0] = -np.ma.sqrt(np.abs(skymap[skymap<0]))

my.hpDraw("region_name", "Modelname", skymap,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename, dpi=300, threshold=np.sqrt(14.16)) #zmax=30, , zmax=80 , color="Milagro"
plt.savefig(f"fullsky_{savename}.pdf",dpi=300) #{ "TeVCat": [1, "s"], "size": 20,"markercolor": "grey","labelcolor": "grey","angle": 60,"catext": 0 }

nestid = hp.ring2nest(1024, np.arange(hp.nside2npix(1024)))
nestmap=np.zeros(hp.nside2npix(1024))
nestmap[nestid] = skymap
nestmap = hp.ma(nestmap)
hp.mollview(nestmap, nest=1)
hp.write_map(f"fullsky_{savename}.fits.gz",skymap,overwrite=True)
map2 = my.change_coord(skymap,["C","G"])
hp.write_map(f"fullsky_{savename}.fits",map2,overwrite=True)
# Out:
# 184 sig_no184.txt not found.
# 186 sig_no186.txt not found.
# 192 sig_no192.txt not found.
# 196 sig_no196.txt not found.
# 197 sig_no197.txt not found.
# 201 sig_no201.txt not found.
# 100%|██████████| 768/768 [00:09<00:00, 83.37it/s]
# 225 sig_no225.txt not found.
# 226 sig_no226.txt not found.
# 227 sig_no227.txt not found.
# 228 sig_no228.txt not found.
# 229 sig_no229.txt not found.
# 230 sig_no230.txt not found.
# 231 sig_no231.txt not found.
# 232 sig_no232.txt not found.
# 233 sig_no233.txt not found.
# 234 sig_no234.txt not found.
# 235 sig_no235.txt not found.
# 236 sig_no236.txt not found.
# 237 sig_no237.txt not found.
# 238 sig_no238.txt not found.
# 239 sig_no239.txt not found.
# 240 sig_no240.txt not found.
# 241 sig_no241.txt not found.
# 242 sig_no242.txt not found.
# 243 sig_no243.txt not found.
# 244 sig_no244.txt not found.
# 245 sig_no245.txt not found.
# 246 sig_no246.txt not found.
# 247 sig_no247.txt not found.
# 248 sig_no248.txt not found.
# 249 sig_no249.txt not found.
# 250 sig_no250.txt not found.
# 251 sig_no251.txt not found.
# 252 sig_no252.txt not found.
# 253 sig_no253.txt not found.
# 254 sig_no254.txt not found.
# 255 sig_no255.txt not found.
# 256 sig_no256.txt not found.
# 257 sig_no257.txt not found.
# 258 sig_no258.txt not found.
# 259 sig_no259.txt not found.
# 260 sig_no260.txt not found.
# 261 sig_no261.txt not found.
# 262 sig_no262.txt not found.
# 263 sig_no263.txt not found.
# 264 sig_no264.txt not found.
# 265 sig_no265.txt not found.
# 266 sig_no266.txt not found.
# 267 sig_no267.txt not found.
# 268 sig_no268.txt not found.
# 269 sig_no269.txt not found.
# 270 sig_no270.txt not found.
# 271 sig_no271.txt not found.
# 272 sig_no272.txt not found.
# 273 sig_no273.txt not found.
# 274 sig_no274.txt not found.
# 275 sig_no275.txt not found.
# 276 sig_no276.txt not found.
# 277 sig_no277.txt not found.
# 278 sig_no278.txt not found.
# 279 sig_no279.txt not found.
# 280 sig_no280.txt not found.
# 281 sig_no281.txt not found.
# 282 sig_no282.txt not found.
# 283 sig_no283.txt not found.
# 284 sig_no284.txt not found.
# 285 sig_no285.txt not found.
# 286 sig_no286.txt not found.
# 287 sig_no287.txt not found.
# 288 sig_no288.txt not found.
# 289 sig_no289.txt not found.
# 290 sig_no290.txt not found.
# 291 sig_no291.txt not found.
# 292 sig_no292.txt not found.
# 293 sig_no293.txt not found.
# 294 sig_no294.txt not found.
# 295 sig_no295.txt not found.
# 296 sig_no296.txt not found.
# 297 sig_no297.txt not found.
# 298 sig_no298.txt not found.
# 299 sig_no299.txt not found.
# 300 sig_no300.txt not found.
# 301 sig_no301.txt not found.
# 302 sig_no302.txt not found.
# 303 sig_no303.txt not found.
# 304 sig_no304.txt not found.
# 305 sig_no305.txt not found.
# 306 sig_no306.txt not found.
# 307 sig_no307.txt not found.
# 308 sig_no308.txt not found.
# 309 sig_no309.txt not found.
# 310 sig_no310.txt not found.
# 311 sig_no311.txt not found.
# 312 sig_no312.txt not found.
# 313 sig_no313.txt not found.
# 314 sig_no314.txt not found.
# 315 sig_no315.txt not found.
# 316 sig_no316.txt not found.
# 317 sig_no317.txt not found.
# 318 sig_no318.txt not found.
# 319 sig_no319.txt not found.
# 320 sig_no320.txt not found.
# 321 sig_no321.txt not found.
# 322 sig_no322.txt not found.
# 323 sig_no323.txt not found.
# 324 sig_no324.txt not found.
# 325 sig_no325.txt not found.
# 326 sig_no326.txt not found.
# 327 sig_no327.txt not found.
# 328 sig_no328.txt not found.
# 329 sig_no329.txt not found.
# 330 sig_no330.txt not found.
# 331 sig_no331.txt not found.
# 332 sig_no332.txt not found.
# 333 sig_no333.txt not found.
# 334 sig_no334.txt not found.
# 335 sig_no335.txt not found.
# 336 sig_no336.txt not found.
# 337 sig_no337.txt not found.
# 338 sig_no338.txt not found.
# 339 sig_no339.txt not found.
# 340 sig_no340.txt not found.
# 341 sig_no341.txt not found.
# 342 sig_no342.txt not found.
# 343 sig_no343.txt not found.
# 344 sig_no344.txt not found.
# 345 sig_no345.txt not found.
# 346 sig_no346.txt not found.
# 347 sig_no347.txt not found.
# 348 sig_no348.txt not found.
# 349 sig_no349.txt not found.
# 350 sig_no350.txt not found.
# 351 sig_no351.txt not found.
# 352 sig_no352.txt not found.
# 353 sig_no353.txt not found.
# 354 sig_no354.txt not found.
# 355 sig_no355.txt not found.
# 356 sig_no356.txt not found.
# 357 sig_no357.txt not found.
# 358 sig_no358.txt not found.
# 359 sig_no359.txt not found.
# 360 sig_no360.txt not found.
# 361 sig_no361.txt not found.
# 362 sig_no362.txt not found.
# 363 sig_no363.txt not found.
# 364 sig_no364.txt not found.
# 365 sig_no365.txt not found.
# 366 sig_no366.txt not found.
# 367 sig_no367.txt not found.
# 368 sig_no368.txt not found.
# 369 sig_no369.txt not found.
# 370 sig_no370.txt not found.
# 371 sig_no371.txt not found.
# 372 sig_no372.txt not found.
# 373 sig_no373.txt not found.
# 374 sig_no374.txt not found.
# 375 sig_no375.txt not found.
# 376 sig_no376.txt not found.
# 377 sig_no377.txt not found.
# 378 sig_no378.txt not found.
# 379 sig_no379.txt not found.
# 380 sig_no380.txt not found.
# 381 sig_no381.txt not found.
# 382 sig_no382.txt not found.
# 383 sig_no383.txt not found.
# 384 sig_no384.txt not found.
# 385 sig_no385.txt not found.
# 386 sig_no386.txt not found.
# 387 sig_no387.txt not found.
# 388 sig_no388.txt not found.
# 389 sig_no389.txt not found.
# 390 sig_no390.txt not found.
# 391 sig_no391.txt not found.
# 392 sig_no392.txt not found.
# 393 sig_no393.txt not found.
# 394 sig_no394.txt not found.
# 395 sig_no395.txt not found.
# 396 sig_no396.txt not found.
# 397 sig_no397.txt not found.
# 398 sig_no398.txt not found.
# 399 sig_no399.txt not found.
# 400 sig_no400.txt not found.
# 401 sig_no401.txt not found.
# 402 sig_no402.txt not found.
# 403 sig_no403.txt not found.
# 404 sig_no404.txt not found.
# 405 sig_no405.txt not found.
# 406 sig_no406.txt not found.
# 407 sig_no407.txt not found.
# 408 sig_no408.txt not found.
# 409 sig_no409.txt not found.
# 410 sig_no410.txt not found.
# 411 sig_no411.txt not found.
# 412 sig_no412.txt not found.
# 413 sig_no413.txt not found.
# 414 sig_no414.txt not found.
# 415 sig_no415.txt not found.
# 416 sig_no416.txt not found.
# 417 sig_no417.txt not found.
# 418 sig_no418.txt not found.
# 419 sig_no419.txt not found.
# 420 sig_no420.txt not found.
# 421 sig_no421.txt not found.
# 422 sig_no422.txt not found.
# 423 sig_no423.txt not found.
# 424 sig_no424.txt not found.
# 425 sig_no425.txt not found.
# 426 sig_no426.txt not found.
# 427 sig_no427.txt not found.
# 428 sig_no428.txt not found.
# 429 sig_no429.txt not found.
# 430 sig_no430.txt not found.
# 431 sig_no431.txt not found.
# 432 sig_no432.txt not found.
# 433 sig_no433.txt not found.
# 434 sig_no434.txt not found.
# 435 sig_no435.txt not found.
# 436 sig_no436.txt not found.
# 437 sig_no437.txt not found.
# 438 sig_no438.txt not found.
# 439 sig_no439.txt not found.
# 440 sig_no440.txt not found.
# 441 sig_no441.txt not found.
# 442 sig_no442.txt not found.
# 443 sig_no443.txt not found.
# 444 sig_no444.txt not found.
# 445 sig_no445.txt not found.
# 446 sig_no446.txt not found.
# 447 sig_no447.txt not found.
# 448 sig_no448.txt not found.
# 449 sig_no449.txt not found.
# 450 sig_no450.txt not found.
# 451 sig_no451.txt not found.
# 452 sig_no452.txt not found.
# 453 sig_no453.txt not found.
# 454 sig_no454.txt not found.
# 455 sig_no455.txt not found.
# 456 sig_no456.txt not found.
# 457 sig_no457.txt not found.
# 458 sig_no458.txt not found.
# 459 sig_no459.txt not found.
# 460 sig_no460.txt not found.
# 461 sig_no461.txt not found.
# 462 sig_no462.txt not found.
# 463 sig_no463.txt not found.
# 464 sig_no464.txt not found.
# 465 sig_no465.txt not found.
# 466 sig_no466.txt not found.
# 467 sig_no467.txt not found.
# 468 sig_no468.txt not found.
# 469 sig_no469.txt not found.
# 470 sig_no470.txt not found.
# 471 sig_no471.txt not found.
# 472 sig_no472.txt not found.
# 473 sig_no473.txt not found.
# 474 sig_no474.txt not found.
# 475 sig_no475.txt not found.
# 476 sig_no476.txt not found.
# 477 sig_no477.txt not found.
# 478 sig_no478.txt not found.
# 479 sig_no479.txt not found.
# 480 sig_no480.txt not found.
# 481 sig_no481.txt not found.
# 482 sig_no482.txt not found.
# 483 sig_no483.txt not found.
# 484 sig_no484.txt not found.
# 485 sig_no485.txt not found.
# 486 sig_no486.txt not found.
# 487 sig_no487.txt not found.
# 488 sig_no488.txt not found.
# 489 sig_no489.txt not found.
# 490 sig_no490.txt not found.
# 491 sig_no491.txt not found.
# 492 sig_no492.txt not found.
# 493 sig_no493.txt not found.
# 494 sig_no494.txt not found.
# 495 sig_no495.txt not found.
# 496 sig_no496.txt not found.
# 497 sig_no497.txt not found.
# 498 sig_no498.txt not found.
# 499 sig_no499.txt not found.
# 500 sig_no500.txt not found.
# 501 sig_no501.txt not found.
# 502 sig_no502.txt not found.
# 503 sig_no503.txt not found.
# 504 sig_no504.txt not found.
# 505 sig_no505.txt not found.
# 506 sig_no506.txt not found.
# 507 sig_no507.txt not found.
# 508 sig_no508.txt not found.
# 509 sig_no509.txt not found.
# 510 sig_no510.txt not found.
# 511 sig_no511.txt not found.
# 512 sig_no512.txt not found.
# 513 sig_no513.txt not found.
# 514 sig_no514.txt not found.
# 515 sig_no515.txt not found.
# 516 sig_no516.txt not found.
# 517 sig_no517.txt not found.
# 518 sig_no518.txt not found.
# 519 sig_no519.txt not found.
# 520 sig_no520.txt not found.
# 521 sig_no521.txt not found.
# 522 sig_no522.txt not found.
# 523 sig_no523.txt not found.
# 524 sig_no524.txt not found.
# 525 sig_no525.txt not found.
# 526 sig_no526.txt not found.
# 527 sig_no527.txt not found.
# 528 sig_no528.txt not found.
# 529 sig_no529.txt not found.
# 530 sig_no530.txt not found.
# 531 sig_no531.txt not found.
# 532 sig_no532.txt not found.
# 533 sig_no533.txt not found.
# 534 sig_no534.txt not found.
# 535 sig_no535.txt not found.
# 536 sig_no536.txt not found.
# 537 sig_no537.txt not found.
# 538 sig_no538.txt not found.
# 539 sig_no539.txt not found.
# 540 sig_no540.txt not found.
# 541 sig_no541.txt not found.
# 542 sig_no542.txt not found.
# 543 sig_no543.txt not found.
# 544 sig_no544.txt not found.
# 545 sig_no545.txt not found.
# 546 sig_no546.txt not found.
# 547 sig_no547.txt not found.
# 548 sig_no548.txt not found.
# 549 sig_no549.txt not found.
# 550 sig_no550.txt not found.
# 551 sig_no551.txt not found.
# 552 sig_no552.txt not found.
# 553 sig_no553.txt not found.
# 554 sig_no554.txt not found.
# 555 sig_no555.txt not found.
# 556 sig_no556.txt not found.
# 557 sig_no557.txt not found.
# 558 sig_no558.txt not found.
# 559 sig_no559.txt not found.
# 560 sig_no560.txt not found.
# 561 sig_no561.txt not found.
# 562 sig_no562.txt not found.
# 563 sig_no563.txt not found.
# 564 sig_no564.txt not found.
# 565 sig_no565.txt not found.
# 566 sig_no566.txt not found.
# 567 sig_no567.txt not found.
# 568 sig_no568.txt not found.
# 569 sig_no569.txt not found.
# 570 sig_no570.txt not found.
# 571 sig_no571.txt not found.
# 572 sig_no572.txt not found.
# 573 sig_no573.txt not found.
# 574 sig_no574.txt not found.
# 575 sig_no575.txt not found.
# 576 sig_no576.txt not found.
# 577 sig_no577.txt not found.
# 578 sig_no578.txt not found.
# 579 sig_no579.txt not found.
# 580 sig_no580.txt not found.
# 581 sig_no581.txt not found.
# 582 sig_no582.txt not found.
# 583 sig_no583.txt not found.
# 584 sig_no584.txt not found.
# 585 sig_no585.txt not found.
# 586 sig_no586.txt not found.
# 587 sig_no587.txt not found.
# 588 sig_no588.txt not found.
# 589 sig_no589.txt not found.
# 590 sig_no590.txt not found.
# 591 sig_no591.txt not found.
# 592 sig_no592.txt not found.
# 593 sig_no593.txt not found.
# 594 sig_no594.txt not found.
# 595 sig_no595.txt not found.
# 596 sig_no596.txt not found.
# 597 sig_no597.txt not found.
# 598 sig_no598.txt not found.
# 599 sig_no599.txt not found.
# 600 sig_no600.txt not found.
# 601 sig_no601.txt not found.
# 602 sig_no602.txt not found.
# 603 sig_no603.txt not found.
# 604 sig_no604.txt not found.
# 605 sig_no605.txt not found.
# 606 sig_no606.txt not found.
# 607 sig_no607.txt not found.
# 608 sig_no608.txt not found.
# 609 sig_no609.txt not found.
# 610 sig_no610.txt not found.
# 611 sig_no611.txt not found.
# 612 sig_no612.txt not found.
# 613 sig_no613.txt not found.
# 614 sig_no614.txt not found.
# 615 sig_no615.txt not found.
# 616 sig_no616.txt not found.
# 617 sig_no617.txt not found.
# 618 sig_no618.txt not found.
# 619 sig_no619.txt not found.
# 620 sig_no620.txt not found.
# 621 sig_no621.txt not found.
# 622 sig_no622.txt not found.
# 623 sig_no623.txt not found.
# 624 sig_no624.txt not found.
# 625 sig_no625.txt not found.
# 626 sig_no626.txt not found.
# 627 sig_no627.txt not found.
# 628 sig_no628.txt not found.
# 629 sig_no629.txt not found.
# 630 sig_no630.txt not found.
# 631 sig_no631.txt not found.
# 632 sig_no632.txt not found.
# 633 sig_no633.txt not found.
# 634 sig_no634.txt not found.
# 635 sig_no635.txt not found.
# 636 sig_no636.txt not found.
# 637 sig_no637.txt not found.
# 638 sig_no638.txt not found.
# 639 sig_no639.txt not found.
# 640 sig_no640.txt not found.
# 641 sig_no641.txt not found.
# 642 sig_no642.txt not found.
# 643 sig_no643.txt not found.
# 644 sig_no644.txt not found.
# 645 sig_no645.txt not found.
# 646 sig_no646.txt not found.
# 647 sig_no647.txt not found.
# 648 sig_no648.txt not found.
# 649 sig_no649.txt not found.
# 650 sig_no650.txt not found.
# 651 sig_no651.txt not found.
# 652 sig_no652.txt not found.
# 653 sig_no653.txt not found.
# 654 sig_no654.txt not found.
# 655 sig_no655.txt not found.
# 656 sig_no656.txt not found.
# 657 sig_no657.txt not found.
# 658 sig_no658.txt not found.
# 659 sig_no659.txt not found.
# 660 sig_no660.txt not found.
# 661 sig_no661.txt not found.
# 662 sig_no662.txt not found.
# 663 sig_no663.txt not found.
# 664 sig_no664.txt not found.
# 665 sig_no665.txt not found.
# 666 sig_no666.txt not found.
# 667 sig_no667.txt not found.
# 668 sig_no668.txt not found.
# 669 sig_no669.txt not found.
# 670 sig_no670.txt not found.
# 671 sig_no671.txt not found.
# 672 sig_no672.txt not found.
# 673 sig_no673.txt not found.
# 674 sig_no674.txt not found.
# 675 sig_no675.txt not found.
# 676 sig_no676.txt not found.
# 677 sig_no677.txt not found.
# 678 sig_no678.txt not found.
# 679 sig_no679.txt not found.
# 680 sig_no680.txt not found.
# 681 sig_no681.txt not found.
# 682 sig_no682.txt not found.
# 683 sig_no683.txt not found.
# 684 sig_no684.txt not found.
# 685 sig_no685.txt not found.
# 686 sig_no686.txt not found.
# 687 sig_no687.txt not found.
# 688 sig_no688.txt not found.
# 689 sig_no689.txt not found.
# 690 sig_no690.txt not found.
# 691 sig_no691.txt not found.
# 692 sig_no692.txt not found.
# 693 sig_no693.txt not found.
# 694 sig_no694.txt not found.
# 695 sig_no695.txt not found.
# 696 sig_no696.txt not found.
# 697 sig_no697.txt not found.
# 698 sig_no698.txt not found.
# 699 sig_no699.txt not found.
# 700 sig_no700.txt not found.
# 701 sig_no701.txt not found.
# 702 sig_no702.txt not found.
# 703 sig_no703.txt not found.
# 704 sig_no704.txt not found.
# 705 sig_no705.txt not found.
# 706 sig_no706.txt not found.
# 707 sig_no707.txt not found.
# 708 sig_no708.txt not found.
# 709 sig_no709.txt not found.
# 710 sig_no710.txt not found.
# 711 sig_no711.txt not found.
# 712 sig_no712.txt not found.
# 713 sig_no713.txt not found.
# 714 sig_no714.txt not found.
# 715 sig_no715.txt not found.
# 716 sig_no716.txt not found.
# 717 sig_no717.txt not found.
# 718 sig_no718.txt not found.
# 719 sig_no719.txt not found.
# 720 sig_no720.txt not found.
# 721 sig_no721.txt not found.
# 722 sig_no722.txt not found.
# 723 sig_no723.txt not found.
# 724 sig_no724.txt not found.
# 725 sig_no725.txt not found.
# 726 sig_no726.txt not found.
# 727 sig_no727.txt not found.
# 728 sig_no728.txt not found.
# 729 sig_no729.txt not found.
# 730 sig_no730.txt not found.
# 731 sig_no731.txt not found.
# 732 sig_no732.txt not found.
# 733 sig_no733.txt not found.
# 734 sig_no734.txt not found.
# 735 sig_no735.txt not found.
# 736 sig_no736.txt not found.
# 737 sig_no737.txt not found.
# 738 sig_no738.txt not found.
# 739 sig_no739.txt not found.
# 740 sig_no740.txt not found.
# 741 sig_no741.txt not found.
# 742 sig_no742.txt not found.
# 743 sig_no743.txt not found.
# 744 sig_no744.txt not found.
# 745 sig_no745.txt not found.
# 746 sig_no746.txt not found.
# 747 sig_no747.txt not found.
# 748 sig_no748.txt not found.
# 749 sig_no749.txt not found.
# 750 sig_no750.txt not found.
# 751 sig_no751.txt not found.
# 752 sig_no752.txt not found.
# 753 sig_no753.txt not found.
# 754 sig_no754.txt not found.
# 755 sig_no755.txt not found.
# 756 sig_no756.txt not found.
# 757 sig_no757.txt not found.
# 758 sig_no758.txt not found.
# 759 sig_no759.txt not found.
# 760 sig_no760.txt not found.
# 761 sig_no761.txt not found.
# 762 sig_no762.txt not found.
# 763 sig_no763.txt not found.
# 764 sig_no764.txt not found.
# 765 sig_no765.txt not found.
# 766 sig_no766.txt not found.
# 767 sig_no767.txt not found.
# WARNING UserWarning: Warning: converting a masked element to nan.
#
#
# WARNING UserWarning: No contour levels were found within the data range.
#
# setting the output map dtype to [dtype('float64')]
# setting the output map dtype to [dtype('float64')]

# %%
hp.mollview(skymap, title="LHAASO full sky", xsize=2048)

# %%
np.ma.max(skymap)

# %%
ss2 = hp.sphtfunc.smoothing(skymap,sigma=np.radians(0.5))

# %%
mapg2 = my.change_coord(ss2,["C","G"])

# %%
my.hpDraw("region_name", "Modelname", mapg2,0,0,skyrange=(0,360,-90,90),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", mapg,0,0,skyrange=(0,360,-90,90),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", ss2,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", ss2,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", ss2,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
from scipy.optimize import curve_fit
def gaussian(x,a,mu,sigma):
    return a*np.exp(-((x-mu)/sigma)**2/2)
nside=2**10
npix=hp.nside2npix(nside)
pixarea = 4 * np.pi/npix


pixIdx = hp.nside2npix(nside) # number of pixels I can get from this nside
pixIdx = np.arange(pixIdx) # pixel index numbers
new_lats = 90-hp.pix2ang(nside, pixIdx)[0]*180/np.pi # thetas I need to populate with interpolated theta values
new_lons = hp.pix2ang(nside, pixIdx)[1]*180/np.pi # phis, same
mask = (new_lats>15 )  & (new_lats < 20 ) & (new_lons>250) * (new_lons<255)
ra_J0057, dec_J0057 =  14,63.5
ra1,dec1=ra_J0057, dec_J0057

data_radius = 6.0
S = skymap[mask]
S = my.maskdiskout(skymap, ra1, dec1, 6)
bin_y,bin_x,patches = plt.hist(S.compressed(),bins=100)
plt.yscale("log")
plt.xlim(-10,10)
plt.close()
bin_x=np.array(bin_x)
bin_y=np.array(bin_y)
fit_range = np.logical_and(bin_x>-5, bin_x<5)
wdt=(bin_x[1]-bin_x[0])/2.
try:
    popt, pcov = curve_fit(
        gaussian,
        bin_x[fit_range] + wdt,
        bin_y[fit_range[:-1]],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
except (ValueError, IndexError):
    popt, pcov = curve_fit(
        gaussian,
        bin_x[:100] + wdt,
        bin_y[:100],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
#popt,pcov = curve_fit(gaussian,bin_x[fit_range[0:-1]]+(bin_x[1]-bin_x[0])/2.,bin_y[fit_range[0:-1]],bounds=([100,-2,0],[50000000,2,10]))
print("************************")
print(popt)
print("************************")
print("max Significance= %.1f"%(max(S.compressed())))

plt.figure()
#plt.plot([0.,0.],[1,1e6],'k--',linewidth=0.5)
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], 0, 1),
    '--',
    label='expectation',
)
plt.plot((bin_x[:100] + bin_x[1:101]) / 2, bin_y, label="data")
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], popt[1], popt[2]),
    '--',
    label='fit',
)
plt.yscale('log')
plt.xlim(-10,10)
plt.ylim(1,max(bin_y*2))
plt.grid(True)
plt.text(-9.5,max(bin_y),'mean = %f\n width = %f'%(popt[1],popt[2]))
plt.xlabel(r'Significance($\sigma$)')
plt.ylabel("entries")
plt.legend()
