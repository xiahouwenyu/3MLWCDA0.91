# %%
from astroquery.vizier import Vizier
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
import os
sys.path.append("/data/home/cwy/Science/3MLWCDA/Standard/src")

import mylib as my
from tqdm import tqdm
import healpy as hp
from importlib import reload
# Out:
# Welcome to JupyROOT 6.24/06
# 19:23:32 WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=159420;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=544104;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
# 19:23:33 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=858178;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=980267;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
# ...

# %%
resultsHII = my.drawcatsimple(my.LHAASOCat, my.FASTHIIcat, catinfo = {"name":"HII-region", "RA":"GLON", "DEC":"GLAT", "color":"Radius", "size":"Radius"}, ifcut=1, ifbkg=1)
resultsHII.to_csv('HIIcat.csv')
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 931.16it/s]

# %%
resultsMC = my.drawcatsimple(my.LHAASOCat, my.MCcat, catinfo = {"name":"ID", "RA":"GLON", "DEC":"GLAT", "color":"d0"}, ifcut=1, ifbkg=1, coor="G", catname="MCcat", skyrange=(10,120,-3,3)) #, yrange=(-20, 20)
resultsMC.to_csv('MCcat.csv')
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 680.86it/s]
